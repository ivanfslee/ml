# %%
print('Aloha World')
# Out:
# Aloha World

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
p = np.linspace(0, 20, 100)
plt.plot(p, np.sin(15 * p))
plt.plot()
# Out:
# []

# %%
#Download and install Python Extension for VSCODE

#To create a new jupyter notebook use CTRL + SHIFT + P to open command palette -> Select 'Python: Create New Blank Jupyter Notebook'
    #More info here: https://www.youtube.com/watch?v=_C0vbLV6WdA
